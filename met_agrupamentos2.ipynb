# %%
# Estatistica Multivariada
# Ana júlia da Silva

import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt
import numpy as np
import scipy.cluster.hierarchy as sch
from sklearn.metrics.pairwise import euclidean_distances
import os

# %%
# Caminho para o arquivo baixado
file_path = "D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\matriz_resultante_consolidada.xlsx"
#file_path = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\matriz_resultante_consolidada.xlsx'

# Ler o arquivo Excel
data = pd.read_excel(file_path)

# Exibir os primeiros registros da tabela
#print(df.head())

#AMOSTRA 1
am1 = 'Raios (m) 1'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am1 = pd.to_numeric(data[am1], errors='coerce').notnull()
valores_am1 = data.loc[filtro_numeros_am1 & (data.index != 0), am1]
#print(valores_am1.head())
# Calcular a média dos valores numéricos
media_am1 = (4/3*np.pi *(0.1*valores_am1.mean())**3)#/(0.1*data.loc[0, am1])

#AMOSTRA 2
am2 = 'Raios (m) 2'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am2 = pd.to_numeric(data[am2], errors='coerce').notnull()
valores_am2 = data.loc[filtro_numeros_am2 & (data.index != 0), am2]
#print(valores_am2.head())
# Calcular a média dos valores numéricos
media_am2 = (4/3*np.pi *(0.1*valores_am2.mean())**3)#/(0.1*data.loc[0, am2]) ##considerando agr a média do olume da bolha

#AMOSTRA 3
am3 = 'Raios (m) 3'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am3 = pd.to_numeric(data[am1], errors='coerce').notnull()
valores_am3 = data.loc[filtro_numeros_am3 & (data.index != 0), am3]
#print(valores_am3.head())
# Calcular a média dos valores numéricos
media_am3 = (4/3*np.pi *(0.1*valores_am3.mean())**3)#/(0.1*data.loc[0, am3])

#AMOSTRA 4
am4 = 'Raios (m) 4'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am4 = pd.to_numeric(data[am1], errors='coerce').notnull()
valores_am4 = data.loc[filtro_numeros_am4 & (data.index != 0), am4]
#print(valores_am4.head())
# Calcular a média dos valores numéricos
media_am4 = (4/3*np.pi *(0.1*valores_am4.mean())**3)#/(0.1*data.loc[0, am4])

#AMOSTRA 5
am5 = 'Raios (m) 5'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am5 = pd.to_numeric(data[am5], errors='coerce').notnull()
valores_am5 = data.loc[filtro_numeros_am5 & (data.index != 0), am5]
#print(valores_am5.head())
# Calcular a média dos valores numéricos
media_am5 = (4/3*np.pi *(0.1*valores_am5.mean())**3)#/(0.1*data.loc[0, am5])

#AMOSTRA 6
am6 = 'Raios (m) 6'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am6 = pd.to_numeric(data[am6], errors='coerce').notnull()
valores_am6 = data.loc[filtro_numeros_am6 & (data.index != 0), am6]
#print(valores_am6.head())
# Calcular a média dos valores numéricos
media_am6 = (4/3*np.pi *(0.1*valores_am6.mean())**3)#/(0.1*data.loc[0, am6])

#AMOSTRA 7
am7 = 'Raios (m) 7'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am7 = pd.to_numeric(data[am7], errors='coerce').notnull()
valores_am7 = data.loc[filtro_numeros_am7 & (data.index != 0), am7]
#print(valores_am7.head())
# Calcular a média dos valores numéricos
media_am7 = (4/3*np.pi *(valores_am7.mean())**3)#/data.loc[0, am7]
#AMOSTRA 8
am8 = 'Raios (m) 8'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am8 = pd.to_numeric(data[am8], errors='coerce').notnull()
valores_am8 = data.loc[filtro_numeros_am8 & (data.index != 0), am8]
#print(valores_am8.head())
# Calcular a média dos valores numéricos
media_am8 = (4/3*np.pi *(valores_am8.mean())**3)#/data.loc[0, am8]

#AMOSTRA 9
am9 = 'Raios (m) 9'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am9 = pd.to_numeric(data[am9], errors='coerce').notnull()
valores_am9 = data.loc[filtro_numeros_am9 & (data.index != 0), am9]
#print(valores_am9.head())
# Calcular a média dos valores numéricos
media_am9 = (4/3*np.pi *(valores_am9.mean())**3)#/data.loc[0, am9]

#AMOSTRA 10
am10 = 'Raios (m) 10'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am10 = pd.to_numeric(data[am10], errors='coerce').notnull()
valores_am10 = data.loc[filtro_numeros_am10 & (data.index != 0), am10]
#print(valores_am10.head())
# Calcular a média dos valores numéricos
media_am10 = (4/3*np.pi *(valores_am10.mean())**3)#/data.loc[0, am10]

#AMOSTRA 11
am11 = 'Raios (m) 11'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am11 = pd.to_numeric(data[am11], errors='coerce').notnull()
valores_am11 = data.loc[filtro_numeros_am11 & (data.index != 0), am11]
#print(valores_am11.head())
# Calcular a média dos valores numéricos
media_am11 = (4/3*np.pi *(valores_am11.mean())**3)#/data.loc[0, am11]

#AMOSTRA 12
am12= 'Raios (m) 12'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am12 = pd.to_numeric(data[am12], errors='coerce').notnull()
valores_am12 = data.loc[filtro_numeros_am12 & (data.index != 0), am12]
#print(valores_am12.head())
# Calcular a média dos valores numéricos
media_am12 = (4/3*np.pi *(valores_am12.mean())**3)#/data.loc[0, am12]

#AMOSTRA 13
am13 = 'Raios (m) 13'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am13 = pd.to_numeric(data[am13], errors='coerce').notnull()
valores_am13 = data.loc[filtro_numeros_am13 & (data.index != 0), am13]
#print(valores_am13.head())
# Calcular a média dos valores numéricos
media_am13 = (4/3*np.pi *(valores_am13.mean())**3)#/data.loc[0, am13]

#AMOSTRA 14
am14 = 'Raios (m) 14'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am14 = pd.to_numeric(data[am14], errors='coerce').notnull()
valores_am14 = data.loc[filtro_numeros_am14 & (data.index != 0), am14]
#print(valores_am14.head())
# Calcular a média dos valores numéricos
media_am14 = (4/3*np.pi *(valores_am14.mean())**3)#/data.loc[0, am14]

#AMOSTRA 15
am15 = 'Raios (m) 15'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am15 = pd.to_numeric(data[am15], errors='coerce').notnull()
valores_am15 = data.loc[filtro_numeros_am15 & (data.index != 0), am15]
#print(valores_am15.head())
# Calcular a média dos valores numéricos
media_am15= (4/3*np.pi *(valores_am15.mean())**3)#/data.loc[0, am15]

#AMOSTRA 16
am16 = 'Raios (m) 16'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am16 = pd.to_numeric(data[am16], errors='coerce').notnull()
valores_am16 = data.loc[filtro_numeros_am16 & (data.index != 0), am16]
#print(valores_am16.head())
# Calcular a média dos valores numéricos
media_am16 = (4/3*np.pi *(valores_am16.mean())**3)#/data.loc[0, am16]

#AMOSTRA 17
am17 = 'Raios (m) 17'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am17 = pd.to_numeric(data[am17], errors='coerce').notnull()
valores_am17 = data.loc[filtro_numeros_am17 & (data.index != 0), am17]
#print(valores_am17.head())
# Calcular a média dos valores numéricos
media_am17 = (4/3*np.pi *(valores_am17.mean())**3)#/data.loc[0, am17]

#AMOSTRA 18
am18 = 'Raios (m) 18'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am18 = pd.to_numeric(data[am18], errors='coerce').notnull()
valores_am18 = data.loc[filtro_numeros_am18 & (data.index != 0), am18]
#print(valores_am18.head())
# Calcular a média dos valores numéricos
media_am18 = (4/3*np.pi *(valores_am18.mean())**3)#/data.loc[0, am18]

#AMOSTRA 19
am19 = 'Raios (m) 19'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am19 = pd.to_numeric(data[am19], errors='coerce').notnull()
valores_am19 = data.loc[filtro_numeros_am19 & (data.index != 0), am19]
#print(valores_am19.head())
# Calcular a média dos valores numéricos
media_am19 = (4/3*np.pi *(valores_am19.mean())**3)#/data.loc[0, am19]

#AMOSTRA 20
am20 = 'Raios (m) 20'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am20 = pd.to_numeric(data[am20], errors='coerce').notnull()
valores_am20 = data.loc[filtro_numeros_am20 & (data.index != 0), am20]
#print(valores_am20.head())
# Calcular a média dos valores numéricos
media_am20 = (4/3*np.pi *(valores_am20.mean())**3)#/data.loc[0, am20]

#AMOSTRA 21
am21 = 'Raios (m) 21'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am21 = pd.to_numeric(data[am21], errors='coerce').notnull()
valores_am21 = data.loc[filtro_numeros_am21 & (data.index != 0), am21]
##print(valores_am21.head())
# Calcular a média dos valores numéricos
media_am21 = (4/3*np.pi *(valores_am21.mean())**3)#/data.loc[0, am21]

#AMOSTRA 22
am22 = 'Raios (m) 22'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am22 = pd.to_numeric(data[am22], errors='coerce').notnull()
valores_am22 = data.loc[filtro_numeros_am22 & (data.index != 0), am22]
#print(valores_am22.head())
# Calcular a média dos valores numéricos
media_am22 = (4/3*np.pi *(valores_am22.mean())**3)#/data.loc[0, am22]

#AMOSTRA 23
am23 = 'Raios (m) 23'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am23 = pd.to_numeric(data[am23], errors='coerce').notnull()
valores_am23 = data.loc[filtro_numeros_am23 & (data.index != 0), am23]
#print(valores_am23.head())
# Calcular a média dos valores numéricos
media_am23 = (4/3*np.pi *(valores_am23.mean())**3)#/data.loc[0, am23]

#AMOSTRA 24
am24 = 'Raios (m) 24'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am24 = pd.to_numeric(data[am24], errors='coerce').notnull()
valores_am24 = data.loc[filtro_numeros_am24 & (data.index != 0), am24]
#print(valores_am24.head())
# Calcular a média dos valores numéricos
media_am24 = (4/3*np.pi *(valores_am24.mean())**3)#/data.loc[0, am24]

#AMOSTRA 25
am25 = 'Raios (m) 25'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am25 = pd.to_numeric(data[am25], errors='coerce').notnull()
valores_am25 = data.loc[filtro_numeros_am25 & (data.index != 0), am25]
#print(valores_am25.head())
# Calcular a média dos valores numéricos
media_am25 = (4/3*np.pi *(valores_am25.mean())**3)#/data.loc[0, am25]

#AMOSTRA 26
am26 = 'Raios (m) 26'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am26 = pd.to_numeric(data[am26], errors='coerce').notnull()
valores_am26 = data.loc[filtro_numeros_am26 & (data.index != 0), am26]
#print(valores_am26.head())
# Calcular a média dos valores numéricos
media_am26 = (4/3*np.pi *(valores_am26.mean())**3)#/data.loc[0, am26]

#AMOSTRA 27
am27 = 'Raios (m) 27'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am27 = pd.to_numeric(data[am27], errors='coerce').notnull()
valores_am27 = data.loc[filtro_numeros_am27 & (data.index != 0), am24]
#print(valores_am27.head())
# Calcular a média dos valores numéricos
media_am27 = (4/3*np.pi *(valores_am27.mean())**3)#/data.loc[0, am27]

#AMOSTRA 28
am28 = 'Raios (m) 28'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am28 = pd.to_numeric(data[am28], errors='coerce').notnull()
valores_am28 = data.loc[filtro_numeros_am28 & (data.index != 0), am28]
#print(valores_am28.head())
# Calcular a média dos valores numéricos
media_am28 = (4/3*np.pi *(valores_am28.mean())**3)#/data.loc[0, am28]

#AMOSTRA 29
am29 = 'Raios (m) 29'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am29 = pd.to_numeric(data[am29], errors='coerce').notnull()
valores_am29 = data.loc[filtro_numeros_am29 & (data.index != 0), am29]
#print(valores_am29.head())
# Calcular a média dos valores numéricos
media_am29 = (4/3*np.pi *(valores_am29.mean())**3)#/data.loc[0, am29]

#AMOSTRA 30
am30 = 'Raios (m) 30'
# Filtrar apenas linhas onde os valores na coluna de diâmetros são numéricos
filtro_numeros_am30 = pd.to_numeric(data[am30], errors='coerce').notnull()
valores_am30 = data.loc[filtro_numeros_am30 & (data.index != 0), am30]
#print(valores_am30.head())
# Calcular a média dos valores numéricos
media_am30 = (4/3*np.pi *(valores_am30.mean())**3)#/data.loc[0, am30]
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\A'
# <>:2: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\AnaJu\AppData\Local\Temp\ipykernel_12752\1788384623.py:2: SyntaxWarning: invalid escape sequence '\A'
#   file_path = "D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\matriz_resultante_consolidada.xlsx"

# %%
#___________________Dendograma baseado na distribuição de tamanhos das bolhas______________________________________________
# Criando a matriz original com filtros como colunas
matriz = np.column_stack((
   media_am1, media_am2, media_am3, media_am4, media_am5,
    media_am6, media_am7, media_am8, media_am9, media_am10,
    media_am11, media_am12, media_am13, media_am14, media_am15,
    media_am16, media_am17, media_am18, media_am19, media_am20,
    media_am21, media_am22, media_am23, media_am24, media_am25,
    media_am26, media_am27, media_am28, media_am29, media_am30
    # Adicione mais filtros até filtro_numeros_am30
))

matriz2 = np.column_stack((
    media_am1/data.loc[0, am1], media_am2/data.loc[0, am2], media_am3/data.loc[0, am3], media_am4/data.loc[0, am4], media_am5/data.loc[0, am5],
    media_am6/data.loc[0, am6], media_am7/data.loc[0, am7], media_am8/data.loc[0, am8], media_am9/data.loc[0, am9], media_am10/data.loc[0, am10],
    media_am11/data.loc[0, am11], media_am12/data.loc[0, am12], media_am13/data.loc[0, am13], media_am14/data.loc[0, am14], media_am15/data.loc[0, am15],
    media_am16/data.loc[0, am16], media_am17/data.loc[0, am17], media_am18/data.loc[0, am18], media_am19/data.loc[0, am19], media_am20/data.loc[0, am20],
    media_am21/data.loc[0, am21], media_am22/data.loc[0, am22], media_am23/data.loc[0, am23], media_am24/data.loc[0, am24], media_am25/data.loc[0, am25],
    media_am26/data.loc[0, am26], media_am27/data.loc[0, am27], media_am28/data.loc[0, am28], media_am29/data.loc[0, am29], media_am30/data.loc[0, am30]
    # Adicione mais filtros até filtro_numeros_am30
))
# print(matriz)

# Convertendo para um numpy array para análise
media_array = np.array(matriz)
media_array2 = np.array(matriz2)

# Criando a matriz de distâncias (usando a distância euclidiana)
dissimilarity_matrix = sch.distance.pdist(media_array.reshape(-1, 1), 'euclidean')#braycurtis')
dissimilarity_matrix2 = sch.distance.pdist(media_array2.reshape(-1, 1), 'euclidean')#braycurtis')
#print(dissimilarity_matrix)

# Realizando o agrupamento hierárquico
linkage_matrix = sch.linkage(dissimilarity_matrix, method='ward')
linkage_matrix2 = sch.linkage(dissimilarity_matrix2, method='ward')
#print(linkage_matrix)
#print(dissimilarity_matrix)

# Criando o dendrograma
plt.figure(figsize=(10, 7))
sch.dendrogram(linkage_matrix)
plt.title('Dendrograma com as Médias de cada amostra')
plt.xlabel('Média dos Experimentos')
plt.ylabel('Distância')
plt.show()

plt.figure(figsize=(10, 7))
sch.dendrogram(linkage_matrix2)
plt.title('Dendrograma razão Vmed/Vorig')
plt.xlabel('Média dos Experimentos')
plt.ylabel('Distância')
plt.show()

# Substitua pelas suas variáveis
#velocidades = np.array([0.004814,	0.004592	,	0.004954	,	0.005011	,	0.004881	,	0.005137	,	0.005017	,	0.004911	,	0.004755	,	0.004975	,	0.005032	,	0.004961	,	0.005106	,	0.005022	,	0.005311	,	0.005387	,	0.005309	,	0.004814	,	0.005009	,	0.004952	,	0.00483	,	0.004928	,	0.004632	,	0.005001	,	0.005023,		0.005054,		0.005164	,	0.005148	,	0.004955	,	0.005003])
#medias_diametros = 3/4*1/np.pi*(np.array([matriz]))**(1/3)

velocidades = 4/3*np.pi*(np.array([0.004814,	0.004592	,	0.004954	,	0.005011	,	0.004881	,	0.005137	,	0.005017	,	0.004911	,	0.004755	,	0.004975	,	0.005032	,	0.004961	,	0.005106	,	0.005022	,	0.005311	,	0.005387	,	0.005309	,	0.004814	,	0.005009	,	0.004952	,	0.00483	,	0.004928	,	0.004632	,	0.005001	,	0.005023,		0.005054,		0.005164	,	0.005148	,	0.004955	,	0.005003]))**3
#print(velocidades)
medias_diametros = np.array([matriz])
#print(media_array)



plt.scatter(velocidades, medias_diametros, color='blue', label='Dados experimentais')
plt.xlabel('Bolhas originais')
plt.ylabel('media bolhas cisalhadas')
#plt.title('Bolhas originais')
plt.legend()
plt.show()


""" O dendrograma mostra como as diferentes amostras (1 a 30) estão relacionadas em termos de semelhança. As amostras mais próximas no dendrograma (com distância menor) têm médias mais similares.
As ramificações indicam os níveis de similaridade. Quanto mais próximo da base do dendrograma ocorre a união de duas amostras ou grupos, mais semelhantes elas são.
2. Número de Grupos Potenciais:
Dependendo do nível de corte da distância no eixo vertical, você pode agrupar as amostras em diferentes clusters. Por exemplo:
Se você cortar o dendrograma em uma altura baixa (por exemplo, perto de 0.5), pode ter muitos clusters pequenos.
Se cortar em uma altura maior (por exemplo, perto de 2.0), terá menos grupos maiores, indicando que as amostras agrupadas são mais distantes em termos de suas médias.
3. Interpretação Física dos Clusters:
Os grupos podem refletir diferenças nos tamanhos médios das bolhas relacionadas às condições experimentais, como a vazão do jato, a pressão ou outras variáveis de controle do experimento.
Se algumas amostras apresentam médias muito diferentes, elas formam clusters isolados (ramificações que se conectam ao dendrograma em níveis altos de distância). Isso pode sugerir que certos parâmetros experimentais causaram um efeito significativo nos tamanhos das bolhas.
4. Dissimilaridade:
A distância no eixo vertical representa o grau de dissimilaridade entre as amostras ou clusters. Distâncias maiores indicam que os grupos unidos são menos semelhantes entre si.
Conclusões Práticas:
Você pode usar o dendrograma para determinar quais amostras possuem comportamentos similares em termos de diâmetros médios de bolhas.
Se você estiver testando diferentes condições experimentais, o agrupamento pode indicar quais condições produzem resultados semelhantes e quais produzem resultados distintos.
Com base no dendrograma, você pode decidir quais grupos analisar com mais detalhe ou quais condições ajustarem para aproximar ou separar certos comportamentos de bolhas. """
# Out:
# ' O dendrograma mostra como as diferentes amostras (1 a 30) estão relacionadas em termos de semelhança. As amostras mais próximas no dendrograma (com distância menor) têm médias mais similares.\nAs ramificações indicam os níveis de similaridade. Quanto mais próximo da base do dendrograma ocorre a união de duas amostras ou grupos, mais semelhantes elas são.\n2. Número de Grupos Potenciais:\nDependendo do nível de corte da distância no eixo vertical, você pode agrupar as amostras em diferentes clusters. Por exemplo:\nSe você cortar o dendrograma em uma altura baixa (por exemplo, perto de 0.5), pode ter muitos clusters pequenos.\nSe cortar em uma altura maior (por exemplo, perto de 2.0), terá menos grupos maiores, indicando que as amostras agrupadas são mais distantes em termos de suas médias.\n3. Interpretação Física dos Clusters:\nOs grupos podem refletir diferenças nos tamanhos médios das bolhas relacionadas às condições experimentais, como a vazão do jato, a pressão ou outras variáv
# ...

# %%
#___________________________________Dendograma baseado na similaridade entre as amostras__________________________________
# Specify the file path
file_path1 = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\dadosestatic\800_0.5_0.txt'; file_path2 = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\dadosestatic\800_1.0_0.txt'
file_path3 = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\dadosestatic\mostra1100_0.5_0.txt'; file_path4 = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\dadosestatic\mostra1100_1.0_0.txt'
file_path5 = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\dadosestatic\mostra1400_0.5_0.txt'; file_path6 = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\dadosestatic\mostra1400_1.0_0.txt'
file_path7 = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\dadosestatic\mostra1700_0.5_0.txt'; file_path8 = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\dadosestatic\mostra1700_1.0_0.txt'
file_path9 = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\dadosestatic\mostra2000_0.5_0.txt'; file_path10 = 'D:\Ana_julia\Mestrado PPGEM\Estatistica multivariada\dadosestatic\mostra2000_1.0_0.txt'

bubble_diameters1 = {}; bubble_diameters2 = {}; bubble_diameters3 = {}; bubble_diameters4 = {}; bubble_diameters5 = {}; bubble_diameters6 = {}; bubble_diameters7 = {}; bubble_diameters8 = {}; bubble_diameters9 = {}; bubble_diameters10 = {}

# Extract data from the file
with open(file_path1, 'r') as file:
    for line in file:
        if "Diameters (cm)" in line:
            bubble_diameters1 = eval(line.split(":")[1].strip())
            break

with open(file_path2, 'r') as file:
    for line in file:
        if "Diameters (cm)" in line:
            bubble_diameters2 = eval(line.split(":")[1].strip())
            break

with open(file_path3, 'r') as file:
    for line in file:
        if "Diameters (cm)" in line:
            bubble_diameters3 = eval(line.split(":")[1].strip())
            break

with open(file_path4, 'r') as file:
    for line in file:
        if "Diameters (cm)" in line:
            bubble_diameters4 = eval(line.split(":")[1].strip())
            break

with open(file_path5, 'r') as file:
    for line in file:
        if "Diameters (cm)" in line:
            bubble_diameters5 = eval(line.split(":")[1].strip())
            break

with open(file_path6, 'r') as file:
    for line in file:
        if "Diameters (cm)" in line:
            bubble_diameters6 = eval(line.split(":")[1].strip())
            break

with open(file_path7, 'r') as file:
    for line in file:
        if "Diameters (cm)" in line:
            bubble_diameters7 = eval(line.split(":")[1].strip())
            break

with open(file_path8, 'r') as file:
    for line in file:
        if "Diameters (cm)" in line:
            bubble_diameters8 = eval(line.split(":")[1].strip())
            break

with open(file_path9, 'r') as file:
    for line in file:
        if "Diameters (cm)" in line:
            bubble_diameters9 = eval(line.split(":")[1].strip())
            break
        
with open(file_path10, 'r') as file:
    for line in file:
        if "Diameters (cm)" in line:
            bubble_diameters10 = eval(line.split(":")[1].strip())
            break

diametros1 = np.mean(bubble_diameters1); diametros2 = np.mean(bubble_diameters2); diametros3 = np.mean(bubble_diameters3); diametros4 = np.mean(bubble_diameters4);diametros5 = np.mean(bubble_diameters5);diametros6 = np.mean(bubble_diameters6);diametros7 = np.mean(bubble_diameters7);diametros8 = np.mean(bubble_diameters8);diametros9 = np.mean(bubble_diameters9);diametros10 = np.mean(bubble_diameters10);


#vetor = [diametros1,diametros2,diametros3,diametros4,diametros5,diametros6,diametros7,diametros8,diametros9,diametros10]
vetor = [diametros1,diametros3,diametros5,diametros7,diametros9]

# Nomes dos arquivos
#file_paths = [  800,     800,     1100,     1100,     1400,     1400,     1700,     1700,     2000,     2000 ]
file_paths = [  800,     1100,     1400,     1700,     2000 ]

# Ordenar os nomes das amostras em ordem alfabética
sorted_indices = np.argsort(file_paths)  # Índices ordenados
sorted_file_paths = np.array(file_paths)[sorted_indices]
sorted_diameters = np.array(vetor)[sorted_indices]

# Criar uma matriz com as informações
matrix = np.column_stack((sorted_diameters, sorted_file_paths))

# Convertendo para um numpy array para análise
media_array = np.array(matrix)
#print(media_array)

# Normalizar os dados para que as colunas fiquem na mesma escala
scaler = StandardScaler()
dados_normalizados = scaler.fit_transform(media_array)
#print(dados_normalizados)

# Gerar a linkage matrix para o dendrograma
linkage_matrix = linkage(dados_normalizados, method='ward')
#print(linkage_matrix)

# Criar o dendrograma
plt.figure(figsize=(10, 7))
dendrogram(linkage_matrix, labels=[f"P{i+1}" for i in range(media_array.shape[0])], leaf_rotation=90, leaf_font_size=10)
plt.title("Dendrograma - Dados Normalizados")
plt.xlabel("Pontos")
plt.ylabel("Distância")
plt.show()

""" P1 corresponde ao primeiro par de dados: o primeiro valor de diâmetro e o primeiro valor de vazão (no caso, 800 de vazão e o primeiro valor médio do vetor de diâmetros).
P2 corresponde ao segundo par de dados: o segundo valor de diâmetro e o segundo valor de vazão, e assim por diante. """
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\A'
# <>:3: SyntaxWarning: invalid escape sequence '\A'
# <>:4: SyntaxWarning: invalid escape sequence '\A'
# <>:4: SyntaxWarning: invalid escape sequence '\A'
# <>:5: SyntaxWarning: invalid escape sequence '\A'
# <>:5: SyntaxWarning: invalid escape sequence '\A'
# <>:6: SyntaxWarning: invalid escape sequence '\A'
# <>:6: SyntaxWarning: invalid escape sequence '\A'
# <>:7: SyntaxWarning: invalid escape sequence '\A'
# <>:7: SyntaxWarning: invalid escape sequence '\A'
# <>:3: SyntaxWarning: invalid escape sequence '\A'
# <>:3: SyntaxWarning: invalid escape sequence '\A'
# <>:4: SyntaxWarning: invalid escape sequence '\A'
# <>:4: SyntaxWarning: invalid escape sequence '\A'
# <>:5: SyntaxWarning: invalid escape sequence '\A'
# <>:5: SyntaxWarning: invalid escape sequence '\A'
# <>:6: SyntaxWarning: invalid escape sequence '\A'
# <>:6: SyntaxWarning: invalid escape sequence '\A'
# <>:7: SyntaxWarning: invalid escape sequence '\A'
# ...

# %%
# Substitua pelas suas variáveis
velocidades = np.array([file_paths])
medias_diametros = np.array([vetor])

plt.scatter(velocidades, medias_diametros, color='blue', label='Dados experimentais')
plt.xlabel('Velocidade do Jato')
plt.ylabel('Média do Diâmetro das Bolhas')
plt.title('Relação entre Velocidade do Jato e Média do Diâmetro das Bolhas')
plt.legend()
plt.show()
